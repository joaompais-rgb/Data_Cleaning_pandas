# %% [markdown]
# <a href="https://colab.research.google.com/github/joaompais-rgb/Data_Cleaning_pandas/blob/main/Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = "https://www.sharkattackfile.net/spreadsheets/GSAF5.xls"

# %%
df_shark_attacks = pd.read_excel(url)

# %%
df_shark_attacks.shape
# Out:
# (7125, 23)

# %%
df_shark_attacks.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Fatal Y/N', 'Time', 'Species ',
#        'Source', 'pdf', 'href formula', 'href', 'Case Number', 'Case Number.1',
#        'original order', 'Unnamed: 21', 'Unnamed: 22'],
#       dtype='object')

# %%
df_shark_attacks.info ()

# %%
df_shark_attacks.nunique()

# %%
df_shark_attacks. head ().T
# Out:
#                                                                 0  \
# Date                                               18th September
# Year                                                       2026.0
# Type                                                   Unprovoked
# Country                                                 Australia
# State                                           Western Australia
# Location                                     Sorrento Beach Perth
# Activity                                                 Swimming
# Name                                                  Greg O'Neil
# Sex                                                             M
# Age                                                            63
# Injury                                         Body not recovered
# Fatal Y/N                                                       Y
# Time                                                      1015hrs
# ...

# %%
df_shark_attacks. tail ()

# %%
len(df_shark_attacks) - df_shark_attacks.count()

# %%
len(df_shark_attacks["Age"])
# Out:
# 7125

# %% [markdown]
# - Cambiar  en columna 'Year' de float a int
# - Limpiar columna 'Edad', cambiar de objet a int

# %%
new_df_shark_attacks = df_shark_attacks[['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity', 'Name', 'Sex', 'Age', 'Injury', 'Fatal Y/N', 'Time', 'Species '].copy()]
new_df_shark_attacks.head().T
# Out:
#                                      0  \
# Date                    18th September
# Year                            2026.0
# Type                        Unprovoked
# Country                      Australia
# State                Western Australia
# Location          Sorrento Beach Perth
# Activity                      Swimming
# Name                       Greg O'Neil
# Sex                                  M
# Age                                 63
# Injury              Body not recovered
# Fatal Y/N                            Y
# Time                           1015hrs
# Species    Great White Shark 6m (20ft)
#
#                                                    1  \
# Date                                  16th September
# Year                                          2026.0
# Type                                      Unprovoked
# Country                                       Canada
# State                                         Quebec
# ...

# %% [markdown]
# DATE = PARA PERCIBIR UNA RELACION DE TEMPORADAS DE ATAQUES

# %%
new_df_shark_attacks.shape
# Out:
# (7125, 14)

# %% [markdown]
# NEGOCIO = ESCUELA DE SURF SEGURA
# - Saber la mayor y menor cantidad de ataques segun:
# PAIS, ESTADO, LOCALIDAD
# SEASON ATTACK
# HORA DEL DIA
